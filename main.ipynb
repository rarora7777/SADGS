# %%
# !pip install torch torchvision torchaudio
# !pip install plyfile tqdm websockets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/rarora7777/SADGS.git
# Out:
# Cloning into 'SADGS'...
# remote: Enumerating objects: 1802, done.
# remote: Counting objects: 100% (1802/1802), done.
# remote: Compressing objects: 100% (847/847), done.
# remote: Total 1802 (delta 944), reused 1795 (delta 937), pack-reused 0 (from 0)
# Receiving objects: 100% (1802/1802), 15.18 MiB | 19.93 MiB/s, done.
# Resolving deltas: 100% (944/944), done.

# %%
# %cd /content/SADGS
# Out:
# /content/SADGS

# %%
# !pip install submodules/diff-gaussian-rasterization_structgs
# !pip install submodules/simple-knn
# !pip install submodules/fused-ssim
# Out:
# Processing ./submodules/diff-gaussian-rasterization_structgs
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Processing ./submodules/simple-knn
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("thnhdg/tandt-db")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 651M/651M [00:07<00:00, 95.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/thnhdg/tandt-db/versions/1

# %%
# !export PROJECT_ROOT=/content/SADGS
# !export TANDT_DB_DATASET=$path

# %%
# !git pull
# !bash run_train.sh
# Out:
# Already up to date.
# ...
# Processing scene: drjohnson
# Dataset: /root/.cache/kagglehub/datasets/thnhdg/tandt-db/versions/1
# Mode (Switch): 4
# GPU-ID: 0
# ...
# Running Configuration 4 (Deep Blending)...
# Traceback (most recent call last):
#   File "/content/SADGS/train.py", line 18, in <module>
#     from fused_ssim import fused_ssim as fast_ssim
# ModuleNotFoundError: No module named 'fused_ssim'
